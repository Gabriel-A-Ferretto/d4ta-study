# %%
n1 = int(input(''))
n2 = int(input(''))
n3 = int(input(''))
n4 = int(input(''))
n5 = int(input(''))

soma = n1 * n2 * n3 * n4 * n5 
print(soma)
# Out:
# 120

# %%
funcionarios = [
    {
        "nome": "Carlos Henrique",
        "idade": 29,
        "setor": "Infraestrutura",
        "frase": "Servidor caiu? O Carlos já estava resolvendo antes do alerta chegar."
    },
    {
        "nome": "Marina Souza",
        "idade": 34,
        "setor": "Desenvolvimento Backend",
        "frase": "Transforma café em API escalável."
    },
    {
        "nome": "Lucas Almeida",
        "idade": 26,
        "setor": "Cybersecurity",
        "frase": "Confia em ninguém, nem no próprio Wi-Fi."
    },
    {
        "nome": "Fernanda Lima",
        "idade": 31,
        "setor": "Dados e BI",
        "frase": "Os dados falam. Ela traduz."
    },
    {
        "nome": "Rafael Costa",
        "idade": 38,
        "setor": "Suporte Técnico",
        "frase": "Já reiniciou o computador? Ele pergunta sorrindo, mas falando sério."
    }
]

print(funcionarios)

nomeFuncionarioNovo = str(input('Digite seu nome: '))
idadeFuncionarioNovo = int(input('Digite sua idade: '))
profissaoFuncionarioNovo = str(input('Digite o nome da sua profissão: '))
fraseFuncionarioNovo = str(input('Escreve uma frase que defina seu trabalho: '))

novo_funcionario = {
    "nome": nomeFuncionarioNovo,
    "idade": idadeFuncionarioNovo,
    "setor": profissaoFuncionarioNovo,
    "frase": fraseFuncionarioNovo
}

funcionarios.append(novo_funcionario)
print(funcionarios)
# Out:
# [{'nome': 'Carlos Henrique', 'idade': 29, 'setor': 'Infraestrutura', 'frase': 'Servidor caiu? O Carlos já estava resolvendo antes do alerta chegar.'}, {'nome': 'Marina Souza', 'idade': 34, 'setor': 'Desenvolvimento Backend', 'frase': 'Transforma café em API escalável.'}, {'nome': 'Lucas Almeida', 'idade': 26, 'setor': 'Cybersecurity', 'frase': 'Confia em ninguém, nem no próprio Wi-Fi.'}, {'nome': 'Fernanda Lima', 'idade': 31, 'setor': 'Dados e BI', 'frase': 'Os dados falam. Ela traduz.'}, {'nome': 'Rafael Costa', 'idade': 38, 'setor': 'Suporte Técnico', 'frase': 'Já reiniciou o computador? Ele pergunta sorrindo, mas falando sério.'}]
# ...
