# %%
soma = 1 + 1
print(soma)

hello_friend = 'Hello Word'
print(hello_friend)
# Out:
# 2
# Hello Word

# %%
nomePessoal = input('Digite seu primeiro nome: ')
idadeAtual = input('Digite sua idade: ')
print(nomePessoal)
print(idadeAtual)

print(f'Seu primeiro nome é {nomePessoal} e a sua idade atual é {idadeAtual}')
# Out:
# Gabriel
# 23
# Seu primeiro nome é Gabriel e a sua idade atual é 23

# %% [markdown]
# ### Tipos de Dados

# %%
n1 = 10
n2 = 15
n3 = 2

n1f = 1.75

soma = int(n1) + int(n2)
print(soma) 

idadeSoma =  int(n1) + int(n2) - int(n3)
print(idadeSoma)

print(n1f)

nome = 'Gabriel' # string(str)

print(f'Olá {nome} sua idade é {idadeSoma} anos e sua altura é {n1f}')
# Out:
# 25
# 23
# 1.75
# Olá Gabriel sua idade é 23 anos e sua altura é 1.75

# %% [markdown]
# **Tipos de variáveis**

# %%
varTexto = 'Hello'
n1Inteiro = 10
n1Float = 1.75
print(type(varTexto)) # Verificando que o tipo da variavel
print(type(n1Inteiro))
print(type(n1Float))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
